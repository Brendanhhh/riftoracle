# %%
import os
import json
import csv
import time
import requests
from datetime import datetime, timedelta

# --- Configuration ---
API_KEY = "RGAPI-dad34b87-7c63-4068-becf-6ff3d8c6605a"
REGION = "na1"
REGIONAL_ENDPOINT = "americas"
TIERS = ["IRON", "BRONZE", "SILVER", "GOLD", "PLATINUM", "EMERALD", "DIAMOND"]
DIVISIONS = ["IV", "III", "II", "I"]

# --- Rate limiting setup ---
REQUEST_LIMIT = 100
WINDOW_SECONDS = 120
request_timestamps = []

# --- State and CSV files ---
STATE_FILE = "state.json"
CSV_FILE = "match_ids.csv"

# --- In-memory cache for summoner PUUIDs ---
puuid_cache = {}

# --- Utility functions for state management ---
def load_state():
    if os.path.exists(STATE_FILE):
        with open(STATE_FILE, "r") as f:
            return json.load(f)
    return {}

def save_state(state):
    with open(STATE_FILE, "w") as f:
        json.dump(state, f, indent=4)

# --- Rate limiting ---
def rate_limit_sleep():
    global request_timestamps
    now = datetime.now()
    # Remove timestamps older than the time window
    request_timestamps = [t for t in request_timestamps if t > now - timedelta(seconds=WINDOW_SECONDS)]
    if len(request_timestamps) >= REQUEST_LIMIT:
        oldest = request_timestamps[0]
        sleep_time = (oldest + timedelta(seconds=WINDOW_SECONDS)) - now
        print(f"Rate limit reached. Sleeping {sleep_time.total_seconds():.1f}s")
        time.sleep(max(sleep_time.total_seconds(), 0))
    request_timestamps.append(now)

# --- API call with iterative retry ---
def make_api_call(url):
    while True:
        rate_limit_sleep()
        try:
            response = requests.get(url, headers={"X-Riot-Token": API_KEY})
            if response.status_code == 429:
                retry_after = int(response.headers.get("Retry-After", 10))
                print(f"429 Received. Sleeping {retry_after}s")
                time.sleep(retry_after)
                continue  # Retry the request
            response.raise_for_status()
            return response.json()
        except Exception as e:
            print(f"API Error: {str(e)}")
            return None

# --- API helper functions ---
def get_players(tier, division, page=1):
    url = f"https://{REGION}.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier}/{division}?page={page}"
    return make_api_call(url)

def get_puuid(summoner_id):
    if summoner_id in puuid_cache:
        return puuid_cache[summoner_id]
    url = f"https://{REGION}.api.riotgames.com/lol/summoner/v4/summoners/{summoner_id}"
    data = make_api_call(url)
    puuid = data.get("puuid") if data else None
    puuid_cache[summoner_id] = puuid
    return puuid

def get_matches(puuid, count=10):
    url = f"https://{REGIONAL_ENDPOINT}.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?queue=420&count={count}"
    return make_api_call(url) or []

def save_match(match_id, tier, division):
    path = f"matches/{match_id}.json"
    if os.path.exists(path):
        return False  # Match already saved
    url = f"https://{REGIONAL_ENDPOINT}.api.riotgames.com/lol/match/v5/matches/{match_id}"
    data = make_api_call(url)
    if data:
        with open(path, "w") as f:
            json.dump(data, f)
        save_match_id_csv(match_id, tier, division)
        return True
    return False

def save_match_id_csv(match_id, tier, division):
    file_exists = os.path.exists(CSV_FILE)
    with open(CSV_FILE, "a", newline="") as csvfile:
        writer = csv.writer(csvfile)
        if not file_exists:
            writer.writerow(["match_id", "tier", "division"])  # Header row
        writer.writerow([match_id, tier, division])

# --- Main data collection function ---
def collect_data(matches_per_tier=2):
    os.makedirs("matches", exist_ok=True)
    state = load_state()  # Load progress state

    for tier in TIERS:
        for division in DIVISIONS:
            print(f"\nProcessing {tier} {division}")
            collected = 0
            page = state.get(tier, {}).get(division, 1)
            done = False

            while collected < matches_per_tier and not done:
                players = get_players(tier, division, page)
                if not players:
                    break

                for player in players:
                    if collected >= matches_per_tier:
                        done = True
                        break
                    puuid = get_puuid(player["summonerId"])
                    if not puuid:
                        continue
                    matches = get_matches(puuid, count=10)
                    for match_id in matches[:5]:
                        if collected >= matches_per_tier:
                            done = True
                            break
                        if save_match(match_id, tier, division):
                            collected += 1
                            print(f"Collected {collected}/{matches_per_tier} for {tier} {division}")
                # Save progress for this tier/division after each page
                state.setdefault(tier, {})[division] = page
                save_state(state)
                page += 1
                time.sleep(0.5)  # Buffer between page requests

            # If we've just finished processing Diamond I, stop the entire collection.
            if tier == "DIAMOND" and division == "I":
                print("Finished Diamond I. Stopping further processing.")
                return

if __name__ == "__main__":
    collect_data()
# Out:
# Processing IRON IV
# Collected 1/2 for IRON IV
# Collected 2/2 for IRON IV
#
# Processing IRON III
# Collected 1/2 for IRON III
# Collected 2/2 for IRON III
#
# Processing IRON II
# Collected 1/2 for IRON II
# Collected 2/2 for IRON II
#
# Processing IRON I
# Collected 1/2 for IRON I
# Collected 2/2 for IRON I
#
# Processing BRONZE IV
# Collected 1/2 for BRONZE IV
# Collected 2/2 for BRONZE IV
#
# Processing BRONZE III
# Collected 1/2 for BRONZE III
# Collected 2/2 for BRONZE III
#
# Processing BRONZE II
# Collected 1/2 for BRONZE II
# Collected 2/2 for BRONZE II
#
# Processing BRONZE I
# Collected 1/2 for BRONZE I
# Collected 2/2 for BRONZE I
#
# Processing SILVER IV
# Collected 1/2 for SILVER IV
# Collected 2/2 for SILVER IV
#
# Processing SILVER III
# Collected 1/2 for SILVER III
# Collected 2/2 for SILVER III
#
# Processing SILVER II
# Collected 1/2 for SILVER II
# Collected 2/2 for SILVER II
#
# Processing SILVER I
# Collected 1/2 for SILVER I
# Collected 2/2 for SILVER I
#
# Processing GOLD IV
# Collected 1/2 for GOLD IV
# Collected 2/2 for GOLD IV
#
# Processing GOLD III
# Collected 1/2 for GOLD III
# Collected 2/2 for GOLD III
#
# Processing GOLD II
# Collected 1/2 for GOLD II
# Collected 2/2 for GOLD II
#
# Processing GOLD I
# Collected 1/2 for GOLD I
# Collected 2/2 for GOLD I
#
# Processing PLATINUM IV
# Collected 1/2 for PLATINUM IV
# Collected 2/2 for PLATINUM IV
#
# Processing PLATINUM III
# Collected 1/2 for PLATINUM III
# Collected 2/2 for PLATINUM III
#
# Processing PLATINUM II
# Collected 1/2 for PLATINUM II
# Collected 2/2 for PLATINUM II
#
# Processing PLATINUM I
# Collected 1/2 for PLATINUM I
# Collected 2/2 for PLATINUM I
#
# Processing EMERALD IV
# Rate limit reached. Sleeping 88.6s
# 429 Received. Sleeping 10s
# Collected 1/2 for EMERALD IV
# Collected 2/2 for EMERALD IV
#
# Processing EMERALD III
# Collected 1/2 for EMERALD III
# Collected 2/2 for EMERALD III
#
# Processing EMERALD II
# Collected 1/2 for EMERALD II
# Collected 2/2 for EMERALD II
#
# Processing EMERALD I
# Collected 1/2 for EMERALD I
# Collected 2/2 for EMERALD I
#
# Processing DIAMOND IV
# Collected 1/2 for DIAMOND IV
# Collected 2/2 for DIAMOND IV
#
# Processing DIAMOND III
# Collected 1/2 for DIAMOND III
# Collected 2/2 for DIAMOND III
#
# Processing DIAMOND II
# Collected 1/2 for DIAMOND II
# Collected 2/2 for DIAMOND II
#
# Processing DIAMOND I
# Collected 1/2 for DIAMOND I
# Collected 2/2 for DIAMOND I
# Finished Diamond I. Stopping further processing.

# %%
import os
import json
import csv
import time
import requests
from datetime import datetime, timedelta

# --- Configuration ---
API_KEY = "RGAPI-dad34b87-7c63-4068-becf-6ff3d8c6605a"  # Replace with your API key
REGION = "na1"
REGIONAL_ENDPOINT = "americas"
TIERS = ["IRON", "BRONZE", "SILVER", "GOLD", "PLATINUM", "EMERALD", "DIAMOND"]
# Process divisions in order from I to IV (adjust order if needed)
DIVISIONS = ["I", "II", "III", "IV"]

# --- Rate limiting setup ---
REQUEST_LIMIT = 100
WINDOW_SECONDS = 120
request_timestamps = []

# --- State and CSV files ---
STATE_FILE = "state.json"
CSV_FILE = "match_ids.csv"

# --- In-memory cache for summoner PUUIDs ---
puuid_cache = {}

# --- Utility functions for state management ---
def load_state():
    if os.path.exists(STATE_FILE):
        with open(STATE_FILE, "r") as f:
            return json.load(f)
    return {}

def save_state(state):
    with open(STATE_FILE, "w") as f:
        json.dump(state, f, indent=4)

# --- Rate limiting ---
def rate_limit_sleep():
    global request_timestamps
    now = datetime.now()
    # Remove timestamps older than the time window
    request_timestamps = [t for t in request_timestamps if t > now - timedelta(seconds=WINDOW_SECONDS)]
    if len(request_timestamps) >= REQUEST_LIMIT:
        oldest = request_timestamps[0]
        sleep_time = (oldest + timedelta(seconds=WINDOW_SECONDS)) - now
        print(f"Rate limit reached. Sleeping {sleep_time.total_seconds():.1f}s")
        time.sleep(max(sleep_time.total_seconds(), 0))
    request_timestamps.append(now)

# --- API call with iterative retry ---
def make_api_call(url):
    while True:
        rate_limit_sleep()
        try:
            response = requests.get(url, headers={"X-Riot-Token": API_KEY})
            if response.status_code == 429:
                retry_after = int(response.headers.get("Retry-After", 10))
                print(f"429 Received. Sleeping {retry_after}s")
                time.sleep(retry_after)
                continue  # Retry the request
            response.raise_for_status()
            return response.json()
        except Exception as e:
            print(f"API Error: {str(e)}")
            return None

# --- API helper functions ---
def get_players(tier, division, page=1):
    url = f"https://{REGION}.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier}/{division}?page={page}"
    return make_api_call(url)

def get_puuid(summoner_id):
    if summoner_id in puuid_cache:
        return puuid_cache[summoner_id]
    url = f"https://{REGION}.api.riotgames.com/lol/summoner/v4/summoners/{summoner_id}"
    data = make_api_call(url)
    puuid = data.get("puuid") if data else None
    puuid_cache[summoner_id] = puuid
    return puuid

def get_matches(puuid, count=10):
    url = f"https://{REGIONAL_ENDPOINT}.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?queue=420&count={count}"
    return make_api_call(url) or []

def save_match(match_id, tier, division):
    # Create folder structure: matches/<tier>/<division>
    folder_path = os.path.join("matches", tier.lower(), division)
    os.makedirs(folder_path, exist_ok=True)
    file_path = os.path.join(folder_path, f"{match_id}.json")
    
    if os.path.exists(file_path):
        return False  # Match already saved
    
    url = f"https://{REGIONAL_ENDPOINT}.api.riotgames.com/lol/match/v5/matches/{match_id}"
    data = make_api_call(url)
    if data:
        with open(file_path, "w") as f:
            json.dump(data, f)
        save_match_id_csv(match_id, tier, division)
        return True
    return False

def save_match_id_csv(match_id, tier, division):
    file_exists = os.path.exists(CSV_FILE)
    with open(CSV_FILE, "a", newline="") as csvfile:
        writer = csv.writer(csvfile)
        if not file_exists:
            writer.writerow(["match_id", "tier", "division"])  # Header row
        writer.writerow([match_id, tier, division])

def collect_data(matches_per_tier=5):
    state = load_state()  # Load progress state

    for tier in TIERS:
        # For Diamond, process divisions in reverse order; otherwise, use normal order.
        if tier == "DIAMOND":
            divisions_to_process = list(reversed(DIVISIONS))
        else:
            divisions_to_process = DIVISIONS

        for division in divisions_to_process:
            print(f"\nProcessing {tier} {division}")
            collected = 0
            # Resume from last processed page (if available), otherwise start at page 1.
            page = state.get(tier, {}).get(division, 1)
            done = False

            while collected < matches_per_tier and not done:
                players = get_players(tier, division, page)
                if not players:
                    break  # No more players available

                for player in players:
                    if collected >= matches_per_tier:
                        done = True
                        break
                    puuid = get_puuid(player["summonerId"])
                    if not puuid:
                        continue
                    # Get a list of match IDs for the player (limit to 10, process only first 5)
                    matches = get_matches(puuid, count=10)
                    for match_id in matches[:5]:
                        if collected >= matches_per_tier:
                            done = True
                            break
                        if save_match(match_id, tier, division):
                            collected += 1
                            print(f"Collected {collected}/{matches_per_tier} for {tier} {division}")

                # Save progress for this tier/division after processing each page.
                state.setdefault(tier, {})[division] = page
                save_state(state)
                page += 1
                time.sleep(0.5)  # Buffer between page requests

            # If we're processing Diamond and have just finished Diamond I, then stop entirely.
            if tier == "DIAMOND" and division == "I":
                print("Finished processing Diamond I. Stopping further processing.")
                return

# For Jupyter Notebook usage, simply run:
# collect_data(matches_per_tier=100)

# %%
collect_data(matches_per_tier=1)
# Out:
# Processing IRON I
# Collected 1/1 for IRON I
#
# Processing IRON II
# Collected 1/1 for IRON II
#
# Processing IRON III
# Collected 1/1 for IRON III
#
# Processing IRON IV
# Collected 1/1 for IRON IV
#
# Processing BRONZE I
# Collected 1/1 for BRONZE I
#
# Processing BRONZE II
# Collected 1/1 for BRONZE II
#
# Processing BRONZE III
# Collected 1/1 for BRONZE III
#
# Processing BRONZE IV
# Collected 1/1 for BRONZE IV
#
# Processing SILVER I
# Collected 1/1 for SILVER I
#
# Processing SILVER II
# Collected 1/1 for SILVER II
#
# Processing SILVER III
# Collected 1/1 for SILVER III
#
# Processing SILVER IV
# Collected 1/1 for SILVER IV
#
# Processing GOLD I
# Collected 1/1 for GOLD I
#
# Processing GOLD II
# Collected 1/1 for GOLD II
#
# Processing GOLD III
# Collected 1/1 for GOLD III
#
# Processing GOLD IV
# Collected 1/1 for GOLD IV
#
# Processing PLATINUM I
# Collected 1/1 for PLATINUM I
#
# Processing PLATINUM II
# Collected 1/1 for PLATINUM II
#
# Processing PLATINUM III
# Collected 1/1 for PLATINUM III
#
# Processing PLATINUM IV
# Collected 1/1 for PLATINUM IV
#
# Processing EMERALD I
# Collected 1/1 for EMERALD I
#
# Processing EMERALD II
# Collected 1/1 for EMERALD II
#
# Processing EMERALD III
# Collected 1/1 for EMERALD III
#
# Processing EMERALD IV
# Collected 1/1 for EMERALD IV
#
# Processing DIAMOND IV
# Collected 1/1 for DIAMOND IV
#
# Processing DIAMOND III
# Rate limit reached. Sleeping 86.8s
# Collected 1/1 for DIAMOND III
#
# Processing DIAMOND II
# Collected 1/1 for DIAMOND II
#
# Processing DIAMOND I
# Rate limit reached. Sleeping 0.0s
# Rate limit reached. Sleeping 0.1s
# Collected 1/1 for DIAMOND I
# Finished processing Diamond I. Stopping further processing.
